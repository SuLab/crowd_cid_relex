# %% [markdown]
# # Biocreative V Task 3B: discovering drug-induced diseases from primary text using crowdsourcing

# %% [markdown]
# 2015-06-10 Tong Shu Li<br>
# Last updated 2015-06-29

# %% [markdown]
# We will create the work units we need for CrowdFlower in this notebook.

# %% [markdown]
# First we will need to parse out the data into something useable.

# %%
from collections import Counter
from collections import defaultdict
import matplotlib as plt
import pandas as pd
import random
import sys

# %%
random.seed("2015-06-11:14:46")

# %%
# %matplotlib inline

# %%
sys.path.append("/home/toby/Code/util/")
from file_util import read_file
from web_util import add_simple_tag

from src.get_pubmed_abstract import get_abstract_information

from src.parse_gold import parse_input

# %% [markdown]
# ---

# %% [markdown]
# ### Parse the input files and split into individual papers:

# %%
sample_data = parse_input("data/training", "CDR_sample.txt")

# %%
training_data = parse_input("data/training", "CDR_TrainingSet.txt")

# %%
development_data = parse_input("data/development", "CDR_DevelopmentSet.txt")

# %% [markdown]
# Number of papers in each dataset:

# %%
print len(sample_data)
print len(training_data)
print len(development_data)
# Out:
# 50
# 500
# 500

# %% [markdown]
# ---

# %% [markdown]
# Let's check that each drug-disease relation only has one identifier each:

# %%
def is_mesh_id(mesh_id):
    return len(mesh_id) == 7 and mesh_id[0] in ['C', 'D']

# %%
def check(dataset):
    for paper in dataset:
        for relation in paper.relations:
            assert len(relation.drug.split('|')) == 1
            assert len(relation.disease.split('|')) == 1
            assert is_mesh_id(relation.drug), paper.pmid
            assert is_mesh_id(relation.disease)

# %%
check(sample_data)

# %%
check(training_data)

# %%
check(development_data)

# %% [markdown]
# ---

# %% [markdown]
# ## Check for each annotation in each paper that the indicies of text mentioned actually match what it should be:

# %%
def check_paper_annotations(paper):
    """
    Makes sure that the annotations for a paper are correct.
    """
    text = "{0} {1}".format(paper.title, paper.abstract)
    for annotation in paper.annotations:
        assert text[annotation.start : annotation.stop] == annotation.text

# %%
datasets = [sample_data, training_data, development_data]
for dataset in datasets:
    for paper in dataset:
        check_paper_annotations(paper)

# %% [markdown]
# Thankfully there are no errors in the highlighting of annotations. This is a relief.

# %% [markdown]
# ### Now let's check that the drugs and diseases don't overlap with one another:

# %%
def separate(sub, obj):
    return sub.start > obj.stop or obj.start > sub.stop

def check_separate(paper):
    for i, sub in enumerate(paper.annotations):
        for j, obj in enumerate(paper.annotations):
            if i != j:
                assert separate(sub, obj)
                
def check_no_overlap(dataset):
    for paper in dataset:
        check_separate(paper)

# %%
check_no_overlap(training_data)

# %%
check_no_overlap(development_data)

# %%
def check_drug_disease_overlap(paper):
    """
    Check to see that all pairs of drug-disease do not overlap each other.
    """
    # drugs and diseases don't overlap
    # but, diseases may overlap with other diseases, and same for drugs
    # happens when the identifiers are the same or different
  
    # the code below fails the assertion, but that's ok
    # sample data pmid 9660111 937, 939 
    for i, sub in enumerate(paper.annotations):
        for j, obj in enumerate(paper.annotations):
            if sub.uid != obj.uid:
                assert sub.start > obj.stop or obj.start > sub.stop, "pmid {0} sub {1} obj {2}".format(paper.pmid,
                                                                                                       sub.start,
                                                                                                       obj.start)
    
    for drug in paper.annotations:
        if drug.stype == "chemical":
            for disease in paper.annotations:
                if disease.stype == "disease":
                    assert drug.start > disease.stop or disease.start > drug.stop

# %%
datasets = [sample_data, training_data, development_data]
for i, dataset in enumerate(datasets):
#     print i
    for paper in dataset:
        check_drug_disease_overlap(paper)

# %% [markdown]
# These data are very clean. There will be no highlighting problems down the line. The only difficulty is that some concepts might be subset of other concepts in terms of highlighting.

# %% [markdown]
# ---

# %% [markdown]
# ### How many annotations and relations does each paper have?

# %%
def info(papers):
    points = []
    for paper in papers:
        points.append((len(paper.annotations), len(paper.relations)))
        
    df = pd.DataFrame(points, columns = ["annotations", "relations"])    
    df.plot(figsize = (10, 5))

# %%
info(sample_data)

# %%
info(training_data)

# %%
info(development_data)

# %% [markdown]
# ### I've noticed that some of the annotations for diseases or drugs will have an identifier of "-1". I presume that this is because some of the concepts have not yet been assigned identifiers. However, since the relationships given seem to be only based on the identifiers, I was wondering if the concepts without identifiers will every be involved in a relationship. If they are, are they mentioned by name, or by something else?

# %% [markdown]
# It seems that indeed there are no relationships between concepts without identifiers in any of the provided data. I will therefore assume that there will never be any relationships involving concepts without any identifier. Therefore, it seems that any annotations where there is no identifier can be ignored for the purposes of trying to find all of the relationships. This is good, because it will reduce the possible number of work units, making the job cheaper.

# %% [markdown]
# Therefore we can now ignore the concepts with no identifiers for our project.

# %% [markdown]
# ## How much would it roughly cost to do the pairwise expansion experiment?

# %% [markdown]
# If, for each paper, we show the crowd all N by M unique drug-disease pairs, then how many work units will there be? This will give us a rough idea of the cost of the experiment.

# %%
def num_work_units(papers):
    work_units = 0
    for paper in papers:
        uniq_drugs = set()
        uniq_diseases = set()
        for annotation in paper.annotations:
            if annotation.stype == "chemical":
                uniq_drugs.add(annotation.uid)
            else:
                assert annotation.stype == "disease"
                uniq_diseases.add(annotation.uid)

        work_units += len(uniq_drugs) * len(uniq_diseases)

    return work_units

# %%
num_work_units(sample_data)
# Out:
# 672

# %%
num_work_units(training_data)
# Out:
# 5399

# %%
num_work_units(development_data)
# Out:
# 5175

# %% [markdown]
# So 5000 work units for 500 papers equals 10 work units (WU) per paper on average. If, we formulate the crowd task as follows:
# 1. Read an abstract.
# 2. Answer 5 true/false questions regarding 5 unique drug-disease pairs, about whether the drug is inducing the disease.
#
# Pay 10 cents per task (5 work units), so 2 cents per work unit. Ask for 5 user judgements per any task.
#
# The cost per paper would therefore be: 2 cents/WU/judgement * 10 WU/paper * 5 judgements = $1.00 per paper

# %% [markdown]
# ### Therefore the cost seems reasonable per paper. Let's actually try out a small experiment to see if people can actually do this job at all:

# %% [markdown]
# We will be measuring two things: precision and recall. Recall = % of the relations that the crowd managed to get correct / total number of relations. Precision = # of relations / # of relations + # of relations crowd says exists but are wrong

# %% [markdown]
# ### Selecting a random sample of papers to use for our experiment:

# %% [markdown]
# Since the sample set (50 papers) is just a small subset of the actual training set, we will just go ahead and pick directly from the training set for simplicity.

# %%
TESTSET_SIZE = 30
testset = random.sample(training_data, TESTSET_SIZE)

for paper in testset:
    print paper.pmid
# Out:
# 11569530
# 11135224
# 1378968
# 19269743
# 8595686
# 16337777
# 10520387
# 17931375
# 3800626
# 9522143
# 17241784
# 2265898
# 6666578
# 15632880
# 8590259
# 12198388
# 2515254
# 1835291
# 12041669
# 7582165
# 2096243
# 7449470
# 2375138
# 6692345
# 17261653
# 18631865
# 1130930
# 10835440
# 15602202
# 16167916

# %% [markdown]
# Now we need to generate the actual work units for CrowdFlower:

# %% [markdown]
# We will need for each work unit:
#
# 1. A unique work unit id.
# 2. The title of the paper, properly highlighted with diseases and drugs.
# 3. The body of the abstract, properly highlighted.
# 4. A set of 5 (too many?) unique drug-disease pairs. (include proper names for each concept?)
#     1. If there aren't enough, then make it blank and display nothing in crowdflower.

# %%
def chunks(a_list, chunk_size):
    """
    Yield successive chunks from the list.
    """
    for i in xrange(0, len(a_list), chunk_size):
        yield a_list[i : i + chunk_size]

# %%
def get_all_work_units(paper):
    """
    Generate all unique drug-disease pairs by unique identifier.
    Return a list.
    
    Also gives a name to each drug or disease.
    """
    uniq = defaultdict(set)
    for annotation in paper.annotations:
        uniq[annotation.stype].add(annotation.uid)
        
    assert len(uniq["chemical"]) <= 15
    assert len(uniq["disease"]) <= 10
        
    name = dict()
    for i, drug in enumerate(uniq["chemical"]):
        name[drug] = "[chemical {0}]".format(chr(ord("A") + i))
        
    for i, disease in enumerate(uniq["disease"]):
        name[disease] = "[disease {0}]".format(chr(ord("P") + i))
        
    return ([(drug, disease) for drug in uniq["chemical"] for disease in uniq["disease"]], name)

# %% [markdown]
# In general there may be many unique diseases and chemicals in any one abstract, so we will need to watch out for those later on when we make the streaming API. The max was 16 diseases and 16 chemicals per any one abstract.

# %% [markdown]
# ##For our small testset of 30 papers, it was ok to start chemicals at A and diseases at P. In the future we will need to update this since in the larger testset this is not true.

# %%
def is_subset(concept, other):
    """
    Checks if the first concept is a subset of the position of the second concept.
    """
    return concept.start >= other.start and concept.stop <= other.stop

# %%
def get_uniq_spans(paper, group):
    """
    Looks through all of the text spans which need to be
    highlighted, and removes those which are subsets of
    another span that needs to be highlighted.
    """
    concepts = set()
    for drug, disease in group:
        concepts.add(drug)
        concepts.add(disease)

    highlight = []
    for annotation in paper.annotations:
        if annotation.uid in concepts:
            highlight.append(annotation)

    temp = []
    for i, annotation in enumerate(highlight):
        temp.append(annotation)

        for j, other in enumerate(highlight):
            if i != j and annotation.stype == other.stype:
                if is_subset(annotation, other):
                    raise Exception("this shouldn't happen")
                    temp.pop()
                    break

    return temp

# %%
def highlight_concepts(text, breaks):
    breaks = sorted(breaks, key = lambda x: x[0])
    
    final = []
    for i in range(len(breaks) - 1):
        if breaks[i][1] == "n":
            s = text[breaks[i][0] : breaks[i+1][0]]
        else:
            s = add_simple_tag("span", breaks[i][1], breaks[i][2])
            
        final.append(s)
        
    return "".join(final)

# %%
def highlight_title(title, uniq_spans, name):
    """
    Highlights the title.
    """
    # index of break, type of break (n = nothing)
    breaks = [(0, "n"), (len(title), "n")]
    
    for span in uniq_spans:
        if span.start < len(title):
            breaks.append((span.start, span.stype, name[span.uid]))
            breaks.append((span.stop, "n"))
            
    return highlight_concepts(title, breaks)

# %%
def highlight_abstract(title_length, abstract, uniq_spans, name):
    # we need to subtract out the length of the title + 1
    breaks = [(0, "n"), (len(abstract), "n")]
    
    for span in uniq_spans:
        if span.start > title_length:
            breaks.append((span.start - title_length - 1, span.stype, name[span.uid]))
            breaks.append((span.stop - title_length - 1, "n"))
            
    return highlight_concepts(abstract, breaks)

# %% [markdown]
# ## Generate the work units for CrowdFlower:

# %% [markdown]
# ### The output we get from pubtator's highlighting is in one huge chunk. This isn't good, because it makes it harder to tell what's going on. We need to break it up so that it is easier to read and parse:

# %% [markdown]
# We will do this using the following strategy:
# 1. Query pubmed with the pmid
# 2. Count the number of chunks, and the starting text of each chunk:
# 3. Replace with div elements for easier formatting.

# %% [markdown]
# We can use the checkboxes element of CrowdFlower to list the variable number of drug-disease pairs to show to our crowd. Since we want to make downstream analysis easier for ourselves, we will use the value of each choice as the actual identifiers given in the biocreative file. However, we want to show human readable names, so we will need another array to hold the names. (do we want to show the official name?)....
# <br>
# I could probably do something like, each of the concepts is highlighted in a different color? I basically want to tell the crowd that one concept may have multiple variants in actual text... But I don't want 10 different colors because that will make things super hard to read..

# %%
def make_sections(text, breaks):
    breaks = sorted(breaks)
    
    final = []
    for i in range(len(breaks) - 1):
        s = text[breaks[i] : breaks[i+1]]
        s = "<p>{0}</p>".format(s)
        final.append(s)
        
    return "".join(final)

# %% [markdown]
# ## Now we finally can put all the functions together and generate the work units:

# %% [markdown]
# The Liquid dynamic generation of choices is not working properly on Crowdflower, so we will have to hard code things and leave empty choices..

# %%
CHOICES_PER_ABSTRACT = 5

data = defaultdict(list)

for paper in testset:
    print paper.pmid
    title, abs_chunks = get_abstract_information(str(paper.pmid))
    
    section_names = []
    if len(abs_chunks) > 1:
        for section in abs_chunks:
            section_name = section[ : section.index(":")]
            section_names.append(section_name)
    
    # make all unique drug-disease pairs into a list
    # group by group size after
    
    work_units, names = get_all_work_units(paper) # the concept id pairs
    
    for group in chunks(work_units, CHOICES_PER_ABSTRACT):
        # this function should be redundant for the official gold data,
        # but might be necessary for the final pipeline
        # therefore we will leave it untouched for now
        uniq_spans = get_uniq_spans(paper, group)        
        
        # now that we know what the unique spans are, we can go ahead
        # and highlight them in the original text
        form_title = highlight_title(paper.title, uniq_spans, names)
        form_abstract = highlight_abstract(len(paper.title), paper.abstract, uniq_spans, names)

        # now use the section names to break it up:
        if len(section_names) > 1:
            section_idx = [len(form_abstract)]
            for name in section_names:
                section_idx.append(form_abstract.index(name))
                
            form_abstract = make_sections(form_abstract, section_idx)
        
        
        # now to make the final bits
        data["pmid"].append(paper.pmid)
        data["form_title"].append(form_title)
        data["form_abstract"].append(form_abstract)
        
        # keep track of the identifiers for each choice,
        # as well as the label for each choice
        
        for i, ids in enumerate(group):
            drug_id = ids[0]
            disease_id = ids[1]
            
            data["choice_{0}_ids".format(i)].append("{0}_induces_{1}".format(drug_id, disease_id))
            
            data["choice_{0}_label".format(i)].append(
                "{0} contributes to or plays a role in {1}".format(
                    add_simple_tag("span", "chemical", names[drug_id]),
                    add_simple_tag("span", "disease", names[disease_id])
                )
            )
            
        # fill in the empty spaces by hand
        for i in range(len(group), 5):
            data["choice_{0}_ids".format(i)].append("empty")
            data["choice_{0}_label".format(i)].append("<strong>Do not</strong> choose this choice.")
# Out:
# 11569530
# 11135224
# 1378968
# 19269743
# 8595686
# 16337777
# 10520387
# 17931375
# 3800626
# 9522143
# 17241784
# 2265898
# 6666578
# 15632880
# 8590259
# 12198388
# 2515254
# 1835291
# 12041669
# 7582165
# 2096243
# 7449470
# 2375138
# 6692345
# 17261653
# 18631865
# 1130930
# 10835440
# 15602202
# 16167916

# %%
# check that each list in the final dictionary has the same number of elements
num_elements = set()
for key, val in data.items():
    num_elements.add(len(val))
    
assert len(num_elements) == 1

# %% [markdown]
# ### Make into a dataframe and output to a text file:

# %%
cf_data = pd.DataFrame(data)

# %% [markdown]
# ### Adding a unique identifier for each work unit:

# %%
cf_data["uniq_id"] = pd.Series(["bcv_id_{0}".format(i) for i in range(len(cf_data))])

# %%
cf_data
# Out:
#                        choice_0_ids  \
# 0           D020117_induces_D016171
# 1           D016593_induces_D017180
# 2           D017239_induces_D013921
# 3           D002945_induces_D013921
# 4           C056507_induces_D013921
# 5           D003404_induces_D006973
# 6           D003404_induces_D005921
# 7           D008094_induces_D007676
# 8           D002211_induces_D010146
# 9           D015742_induces_D010146
# 10          D008012_induces_D014474
# 11          D010862_induces_D013226
# 12          D015742_induces_D013610
# 13          D004809_induces_D017202
# 14          D006493_induces_D003288
# 15          D010423_induces_D009135
# 16          D011318_induces_D006319
# 17          D008727_induces_D009135
# 18          D011239_induces_D009336
# 19          C009265_induces_D001523
# 20          D025101_induces_D012640
# 21          D010396_induces_D001018
# 22          D002857_induces_D006333
# 23          D003404_induces_D006947
# 24          D011188_induces_D003920
# 25          D049971_induces_D051437
# 26          C016986_induces_D015878
# 27          C016986_induces_D004774
# 28          D000109_induces_D012640
# 29          D002217_induces_D014202
# 30          D009538_induces_D012640
# 31          D009388_induces_D014202
# 32          D005996_induces_D010146
# 33  D013806_induces_D002318|D005767
# 34          D010396_induces_D000741
# 35          D003907_induces_D004342
# 36          D010248_induces_D014581
# 37          C017367_induces_D001927
# 38          D004317_induces_D009202
# 39          D008874_induces_D006323
# 40          D005200_induces_D063646
# 41          D001241_induces_D013274
# 42          D003000_induces_D001145
# 43          D009712_induces_D001145
# 44          D020123_induces_D005921
# 45  D005839_induces_D009846|D051437
# 46          D002512_induces_D007683
# 47          D009553_induces_D002544
# 48          D017963_induces_D009395
# 49          D020849_induces_D000568
# 50          D002118_induces_D010024
#
#                                        choice_0_label  \
# 0   <span class="chemical">[chemical A]</span> con...
# 1   <span class="chemical">[chemical C]</span> con...
# 2   <span class="chemical">[chemical A]</span> con...
# 3   <span class="chemical">[chemical B]</span> con...
# 4   <span class="chemical">[chemical C]</span> con...
# 5   <span class="chemical">[chemical A]</span> con...
# 6   <span class="chemical">[chemical A]</span> con...
# 7   <span class="chemical">[chemical B]</span> con...
# 8   <span class="chemical">[chemical A]</span> con...
# 9   <span class="chemical">[chemical A]</span> con...
# 10  <span class="chemical">[chemical C]</span> con...
# 11  <span class="chemical">[chemical A]</span> con...
# 12  <span class="chemical">[chemical A]</span> con...
# 13  <span class="chemical">[chemical B]</span> con...
# 14  <span class="chemical">[chemical A]</span> con...
# 15  <span class="chemical">[chemical A]</span> con...
# 16  <span class="chemical">[chemical A]</span> con...
# 17  <span class="chemical">[chemical A]</span> con...
# 18  <span class="chemical">[chemical C]</span> con...
# 19  <span class="chemical">[chemical A]</span> con...
# 20  <span class="chemical">[chemical B]</span> con...
# 21  <span class="chemical">[chemical A]</span> con...
# 22  <span class="chemical">[chemical A]</span> con...
# 23  <span class="chemical">[chemical B]</span> con...
# 24  <span class="chemical">[chemical C]</span> con...
# 25  <span class="chemical">[chemical D]</span> con...
# 26  <span class="chemical">[chemical A]</span> con...
# 27  <span class="chemical">[chemical A]</span> con...
# 28  <span class="chemical">[chemical A]</span> con...
# 29  <span class="chemical">[chemical C]</span> con...
# 30  <span class="chemical">[chemical F]</span> con...
# 31  <span class="chemical">[chemical H]</span> con...
# 32  <span class="chemical">[chemical A]</span> con...
# 33  <span class="chemical">[chemical A]</span> con...
# 34  <span class="chemical">[chemical A]</span> con...
# 35  <span class="chemical">[chemical A]</span> con...
# 36  <span class="chemical">[chemical B]</span> con...
# 37  <span class="chemical">[chemical A]</span> con...
# 38  <span class="chemical">[chemical A]</span> con...
# 39  <span class="chemical">[chemical A]</span> con...
# 40  <span class="chemical">[chemical A]</span> con...
# 41  <span class="chemical">[chemical B]</span> con...
# 42  <span class="chemical">[chemical A]</span> con...
# 43  <span class="chemical">[chemical B]</span> con...
# 44  <span class="chemical">[chemical A]</span> con...
# 45  <span class="chemical">[chemical A]</span> con...
# 46  <span class="chemical">[chemical B]</span> con...
# 47  <span class="chemical">[chemical A]</span> con...
# 48  <span class="chemical">[chemical A]</span> con...
# 49  <span class="chemical">[chemical A]</span> con...
# 50  <span class="chemical">[chemical B]</span> con...
#
#                choice_1_ids  \
# 0   D020117_induces_D017180
# 1   C010637_induces_D016171
# 2   D017239_induces_D064420
# 3   D002945_induces_D064420
# 4   C056507_induces_D064420
# 5   D003404_induces_D011507
# 6   D008094_induces_D006973
# 7   D008094_induces_D005921
# 8                     empty
# 9   D015742_induces_D014474
# 10                    empty
# 11  D010862_induces_D003643
# 12  D015742_induces_D007022
# 13                    empty
# 14  D006493_induces_D010146
# 15  D010423_induces_D009408
# 16  D011318_induces_D034381
# 17  D008727_induces_D009336
# 18                    empty
# 19  C009265_induces_D012640
# 20  D025101_induces_D004827
# 21  D006820_induces_D001018
# 22  D002857_induces_D006947
# 23  D003404_induces_D003920
# 24  D011188_induces_D051437
# 25  D013148_induces_D006333
# 26  C016986_induces_D003316
# 27                    empty
# 28  D000109_induces_D014202
# 29  D000431_induces_D012640
# 30  D009538_induces_D014202
# 31                    empty
# 32  D005996_induces_D008881
# 33  D013806_induces_D029424
# 34  D000961_induces_D000741
# 35  D003907_induces_D003231
# 36  D000305_induces_D004342
# 37  C017367_induces_D056784
# 38  D004317_induces_D066126
# 39  D008874_induces_D003643
# 40  D005200_induces_D001749
# 41                    empty
# 42  D003000_induces_D002318
# 43  D009712_induces_D002318
# 44  D020123_induces_D051436
# 45  D005839_induces_D007683
# 46  D002512_induces_D007674
# 47  D009553_induces_D003643
# 48  D017963_induces_D007674
# 49  D020849_induces_D010024
# 50  D002118_induces_D054556
#
#                                        choice_1_label  \
# 0   <span class="chemical">[chemical A]</span> con...
# 1   <span class="chemical">[chemical D]</span> con...
# 2   <span class="chemical">[chemical A]</span> con...
# 3   <span class="chemical">[chemical B]</span> con...
# 4   <span class="chemical">[chemical C]</span> con...
# 5   <span class="chemical">[chemical A]</span> con...
# 6   <span class="chemical">[chemical B]</span> con...
# 7   <span class="chemical">[chemical B]</span> con...
# 8         <strong>Do not</strong> choose this choice.
# 9   <span class="chemical">[chemical A]</span> con...
# 10        <strong>Do not</strong> choose this choice.
# 11  <span class="chemical">[chemical A]</span> con...
# 12  <span class="chemical">[chemical A]</span> con...
# 13        <strong>Do not</strong> choose this choice.
# 14  <span class="chemical">[chemical A]</span> con...
# 15  <span class="chemical">[chemical A]</span> con...
# 16  <span class="chemical">[chemical A]</span> con...
# 17  <span class="chemical">[chemical A]</span> con...
# 18        <strong>Do not</strong> choose this choice.
# 19  <span class="chemical">[chemical A]</span> con...
# 20  <span class="chemical">[chemical B]</span> con...
# 21  <span class="chemical">[chemical B]</span> con...
# 22  <span class="chemical">[chemical A]</span> con...
# 23  <span class="chemical">[chemical B]</span> con...
# 24  <span class="chemical">[chemical C]</span> con...
# 25  <span class="chemical">[chemical E]</span> con...
# 26  <span class="chemical">[chemical A]</span> con...
# 27        <strong>Do not</strong> choose this choice.
# 28  <span class="chemical">[chemical A]</span> con...
# 29  <span class="chemical">[chemical D]</span> con...
# 30  <span class="chemical">[chemical F]</span> con...
# 31        <strong>Do not</strong> choose this choice.
# 32  <span class="chemical">[chemical A]</span> con...
# 33  <span class="chemical">[chemical A]</span> con...
# 34  <span class="chemical">[chemical B]</span> con...
# 35  <span class="chemical">[chemical A]</span> con...
# 36  <span class="chemical">[chemical C]</span> con...
# 37  <span class="chemical">[chemical A]</span> con...
# 38  <span class="chemical">[chemical A]</span> con...
# 39  <span class="chemical">[chemical A]</span> con...
# 40  <span class="chemical">[chemical A]</span> con...
# 41        <strong>Do not</strong> choose this choice.
# 42  <span class="chemical">[chemical A]</span> con...
# 43  <span class="chemical">[chemical B]</span> con...
# 44  <span class="chemical">[chemical A]</span> con...
# 45  <span class="chemical">[chemical A]</span> con...
# 46  <span class="chemical">[chemical B]</span> con...
# 47  <span class="chemical">[chemical A]</span> con...
# 48  <span class="chemical">[chemical A]</span> con...
# 49  <span class="chemical">[chemical A]</span> con...
# 50  <span class="chemical">[chemical B]</span> con...
#
#                        choice_2_ids  \
# 0           C063968_induces_D016171
# 1           C010637_induces_D017180
# 2           D017239_induces_D003643
# 3           D002945_induces_D003643
# 4           C056507_induces_D003643
# 5           D003404_induces_D051437
# 6           D008094_induces_D011507
# 7                             empty
# 8                             empty
# 9           D013874_induces_D010146
# 10                            empty
# 11          D010862_induces_D028361
# 12          D015742_induces_D017202
# 13                            empty
# 14                            empty
# 15  D010423_induces_D009408|D020425
# 16          D002045_induces_D006319
# 17          D019821_induces_D009135
# 18                            empty
# 19          C009265_induces_D004827
# 20          D025101_induces_D007676
# 21                            empty
# 22          D002857_induces_D003920
# 23          D003404_induces_D051437
# 24          D049971_induces_D006333
# 25          D013148_induces_D006947
# 26          C016986_induces_D003229
# 27                            empty
# 28          D012964_induces_D012640
# 29          D000431_induces_D014202
# 30          C522374_induces_D012640
# 31                            empty
# 32                            empty
# 33  D009241_induces_D002318|D005767
# 34                            empty
# 35          D003907_induces_D014581
# 36          D000305_induces_D003231
# 37          C017367_induces_D010554
# 38                            empty
# 39  D008874_induces_D012140|D002318
# 40          D005200_induces_D013274
# 41                            empty
# 42          D003000_induces_D006333
# 43          D009712_induces_D006333
# 44          D020123_induces_D011507
# 45          D005839_induces_D007674
# 46          D002512_induces_D051437
# 47          D009553_induces_D007022
# 48                            empty
# 49          D020849_induces_D054556
# 50          D002118_induces_D001851
#
#                                        choice_2_label  \
# 0   <span class="chemical">[chemical B]</span> con...
# 1   <span class="chemical">[chemical D]</span> con...
# 2   <span class="chemical">[chemical A]</span> con...
# 3   <span class="chemical">[chemical B]</span> con...
# 4   <span class="chemical">[chemical C]</span> con...
# 5   <span class="chemical">[chemical A]</span> con...
# 6   <span class="chemical">[chemical B]</span> con...
# 7         <strong>Do not</strong> choose this choice.
# 8         <strong>Do not</strong> choose this choice.
# 9   <span class="chemical">[chemical B]</span> con...
# 10        <strong>Do not</strong> choose this choice.
# 11  <span class="chemical">[chemical A]</span> con...
# 12  <span class="chemical">[chemical A]</span> con...
# 13        <strong>Do not</strong> choose this choice.
# 14        <strong>Do not</strong> choose this choice.
# 15  <span class="chemical">[chemical A]</span> con...
# 16  <span class="chemical">[chemical B]</span> con...
# 17  <span class="chemical">[chemical B]</span> con...
# 18        <strong>Do not</strong> choose this choice.
# 19  <span class="chemical">[chemical A]</span> con...
# 20  <span class="chemical">[chemical B]</span> con...
# 21        <strong>Do not</strong> choose this choice.
# 22  <span class="chemical">[chemical A]</span> con...
# 23  <span class="chemical">[chemical B]</span> con...
# 24  <span class="chemical">[chemical D]</span> con...
# 25  <span class="chemical">[chemical E]</span> con...
# 26  <span class="chemical">[chemical A]</span> con...
# 27        <strong>Do not</strong> choose this choice.
# 28  <span class="chemical">[chemical B]</span> con...
# 29  <span class="chemical">[chemical D]</span> con...
# 30  <span class="chemical">[chemical G]</span> con...
# 31        <strong>Do not</strong> choose this choice.
# 32        <strong>Do not</strong> choose this choice.
# 33  <span class="chemical">[chemical B]</span> con...
# 34        <strong>Do not</strong> choose this choice.
# 35  <span class="chemical">[chemical A]</span> con...
# 36  <span class="chemical">[chemical C]</span> con...
# 37  <span class="chemical">[chemical A]</span> con...
# 38        <strong>Do not</strong> choose this choice.
# 39  <span class="chemical">[chemical A]</span> con...
# 40  <span class="chemical">[chemical A]</span> con...
# 41        <strong>Do not</strong> choose this choice.
# 42  <span class="chemical">[chemical A]</span> con...
# 43  <span class="chemical">[chemical B]</span> con...
# 44  <span class="chemical">[chemical A]</span> con...
# 45  <span class="chemical">[chemical A]</span> con...
# 46  <span class="chemical">[chemical B]</span> con...
# 47  <span class="chemical">[chemical A]</span> con...
# 48        <strong>Do not</strong> choose this choice.
# 49  <span class="chemical">[chemical A]</span> con...
# 50  <span class="chemical">[chemical B]</span> con...
#
#                        choice_3_ids  \
# 0           C063968_induces_D017180
# 1                             empty
# 2           D017239_induces_D009503
# 3           D002945_induces_D009503
# 4           C056507_induces_D009503
# 5           D003404_induces_D007674
# 6           D008094_induces_D051437
# 7                             empty
# 8                             empty
# 9           D013874_induces_D014474
# 10                            empty
# 11          D010862_induces_D004827
# 12          D004809_induces_D013610
# 13                            empty
# 14                            empty
# 15  D010423_induces_D005355|D009135
# 16          D002045_induces_D034381
# 17          D019821_induces_D009336
# 18                            empty
# 19          C009265_induces_D007676
# 20                            empty
# 21                            empty
# 22          D002857_induces_D051437
# 23          D011188_induces_D006333
# 24          D049971_induces_D006947
# 25          D013148_induces_D003920
# 26          C016986_induces_D007022
# 27                            empty
# 28          D012964_induces_D014202
# 29          D011188_induces_D012640
# 30          C522374_induces_D014202
# 31                            empty
# 32                            empty
# 33          D009241_induces_D029424
# 34                            empty
# 35          D010248_induces_D004342
# 36          D000305_induces_D014581
# 37          C017367_induces_D019965
# 38                            empty
# 39                            empty
# 40          D001241_induces_D063646
# 41                            empty
# 42          D003000_induces_D003327
# 43          D009712_induces_D003327
# 44                            empty
# 45          D005839_induces_D051437
# 46                            empty
# 47          D009553_induces_D020521
# 48                            empty
# 49          D020849_induces_D001851
# 50                            empty
#
#                                        choice_3_label  \
# 0   <span class="chemical">[chemical B]</span> con...
# 1         <strong>Do not</strong> choose this choice.
# 2   <span class="chemical">[chemical A]</span> con...
# 3   <span class="chemical">[chemical B]</span> con...
# 4   <span class="chemical">[chemical C]</span> con...
# 5   <span class="chemical">[chemical A]</span> con...
# 6   <span class="chemical">[chemical B]</span> con...
# 7         <strong>Do not</strong> choose this choice.
# 8         <strong>Do not</strong> choose this choice.
# 9   <span class="chemical">[chemical B]</span> con...
# 10        <strong>Do not</strong> choose this choice.
# 11  <span class="chemical">[chemical A]</span> con...
# 12  <span class="chemical">[chemical B]</span> con...
# 13        <strong>Do not</strong> choose this choice.
# 14        <strong>Do not</strong> choose this choice.
# 15  <span class="chemical">[chemical A]</span> con...
# 16  <span class="chemical">[chemical B]</span> con...
# 17  <span class="chemical">[chemical B]</span> con...
# 18        <strong>Do not</strong> choose this choice.
# 19  <span class="chemical">[chemical A]</span> con...
# 20        <strong>Do not</strong> choose this choice.
# 21        <strong>Do not</strong> choose this choice.
# 22  <span class="chemical">[chemical A]</span> con...
# 23  <span class="chemical">[chemical C]</span> con...
# 24  <span class="chemical">[chemical D]</span> con...
# 25  <span class="chemical">[chemical E]</span> con...
# 26  <span class="chemical">[chemical A]</span> con...
# 27        <strong>Do not</strong> choose this choice.
# 28  <span class="chemical">[chemical B]</span> con...
# 29  <span class="chemical">[chemical E]</span> con...
# 30  <span class="chemical">[chemical G]</span> con...
# 31        <strong>Do not</strong> choose this choice.
# 32        <strong>Do not</strong> choose this choice.
# 33  <span class="chemical">[chemical B]</span> con...
# 34        <strong>Do not</strong> choose this choice.
# 35  <span class="chemical">[chemical B]</span> con...
# 36  <span class="chemical">[chemical C]</span> con...
# 37  <span class="chemical">[chemical A]</span> con...
# 38        <strong>Do not</strong> choose this choice.
# 39        <strong>Do not</strong> choose this choice.
# 40  <span class="chemical">[chemical B]</span> con...
# 41        <strong>Do not</strong> choose this choice.
# 42  <span class="chemical">[chemical A]</span> con...
# 43  <span class="chemical">[chemical B]</span> con...
# 44        <strong>Do not</strong> choose this choice.
# 45  <span class="chemical">[chemical A]</span> con...
# 46        <strong>Do not</strong> choose this choice.
# 47  <span class="chemical">[chemical A]</span> con...
# 48        <strong>Do not</strong> choose this choice.
# 49  <span class="chemical">[chemical A]</span> con...
# 50        <strong>Do not</strong> choose this choice.
#
#                        choice_4_ids  \
# 0           D016593_induces_D016171
# 1                             empty
# 2           D017239_induces_D002289
# 3           D002945_induces_D002289
# 4           C056507_induces_D002289
# 5           D003404_induces_D007676
# 6           D008094_induces_D007674
# 7                             empty
# 8                             empty
# 9           D008012_induces_D010146
# 10                            empty
# 11          D010862_induces_D004833
# 12          D004809_induces_D007022
# 13                            empty
# 14                            empty
# 15                            empty
# 16                            empty
# 17          D011239_induces_D009135
# 18                            empty
# 19          D025101_induces_D001523
# 20                            empty
# 21                            empty
# 22          D003404_induces_D006333
# 23          D011188_induces_D006947
# 24          D049971_induces_D003920
# 25          D013148_induces_D051437
# 26          C016986_induces_D015814
# 27                            empty
# 28          D002217_induces_D012640
# 29          D011188_induces_D014202
# 30          D009388_induces_D012640
# 31                            empty
# 32                            empty
# 33                            empty
# 34                            empty
# 35          D010248_induces_D003231
# 36                            empty
# 37                            empty
# 38                            empty
# 39                            empty
# 40          D001241_induces_D001749
# 41                            empty
# 42          D003000_induces_D001919
# 43          D009712_induces_D001919
# 44                            empty
# 45  D002512_induces_D009846|D051437
# 46                            empty
# 47                            empty
# 48                            empty
# 49          D002118_induces_D000568
# 50                            empty
#
#                                        choice_4_label  \
# 0   <span class="chemical">[chemical C]</span> con...
# 1         <strong>Do not</strong> choose this choice.
# 2   <span class="chemical">[chemical A]</span> con...
# 3   <span class="chemical">[chemical B]</span> con...
# 4   <span class="chemical">[chemical C]</span> con...
# 5   <span class="chemical">[chemical A]</span> con...
# 6   <span class="chemical">[chemical B]</span> con...
# 7         <strong>Do not</strong> choose this choice.
# 8         <strong>Do not</strong> choose this choice.
# 9   <span class="chemical">[chemical C]</span> con...
# 10        <strong>Do not</strong> choose this choice.
# 11  <span class="chemical">[chemical A]</span> con...
# 12  <span class="chemical">[chemical B]</span> con...
# 13        <strong>Do not</strong> choose this choice.
# 14        <strong>Do not</strong> choose this choice.
# 15        <strong>Do not</strong> choose this choice.
# 16        <strong>Do not</strong> choose this choice.
# 17  <span class="chemical">[chemical C]</span> con...
# 18        <strong>Do not</strong> choose this choice.
# 19  <span class="chemical">[chemical B]</span> con...
# 20        <strong>Do not</strong> choose this choice.
# 21        <strong>Do not</strong> choose this choice.
# 22  <span class="chemical">[chemical B]</span> con...
# 23  <span class="chemical">[chemical C]</span> con...
# 24  <span class="chemical">[chemical D]</span> con...
# 25  <span class="chemical">[chemical E]</span> con...
# 26  <span class="chemical">[chemical A]</span> con...
# 27        <strong>Do not</strong> choose this choice.
# 28  <span class="chemical">[chemical C]</span> con...
# 29  <span class="chemical">[chemical E]</span> con...
# 30  <span class="chemical">[chemical H]</span> con...
# 31        <strong>Do not</strong> choose this choice.
# 32        <strong>Do not</strong> choose this choice.
# 33        <strong>Do not</strong> choose this choice.
# 34        <strong>Do not</strong> choose this choice.
# 35  <span class="chemical">[chemical B]</span> con...
# 36        <strong>Do not</strong> choose this choice.
# 37        <strong>Do not</strong> choose this choice.
# 38        <strong>Do not</strong> choose this choice.
# 39        <strong>Do not</strong> choose this choice.
# 40  <span class="chemical">[chemical B]</span> con...
# 41        <strong>Do not</strong> choose this choice.
# 42  <span class="chemical">[chemical A]</span> con...
# 43  <span class="chemical">[chemical B]</span> con...
# 44        <strong>Do not</strong> choose this choice.
# 45  <span class="chemical">[chemical B]</span> con...
# 46        <strong>Do not</strong> choose this choice.
# 47        <strong>Do not</strong> choose this choice.
# 48        <strong>Do not</strong> choose this choice.
# 49  <span class="chemical">[chemical B]</span> con...
# 50        <strong>Do not</strong> choose this choice.
#
#                                         form_abstract  \
# 0   1. <span class="disease">[disease P]</span> (<...
# 1   1. <span class="disease">[disease P]</span> (<...
# 2   <p>BACKGROUND: Cisplatin-based chemotherapy co...
# 3   <p>BACKGROUND: <span class="chemical">[chemica...
# 4   <p>BACKGROUND: Cisplatin-based chemotherapy co...
# 5   Rats with lithium-induced <span class="disease...
# 6   Rats with <span class="chemical">[chemical B]<...
# 7   Rats with <span class="chemical">[chemical B]<...
# 8   <span class="disease">[disease P]</span> memor...
# 9   This study investigated <span class="chemical"...
# 10  This study investigated propofol injection pai...
# 11  <span class="disease">[disease R]</span> have ...
# 12  The marked vasodilator and negative inotropic ...
# 13  The marked vasodilator and negative inotropic ...
# 14  <p>AIM: This study was carried out to determin...
# 15  <span class="disease">[disease S]</span> is a ...
# 16  The cause of <span class="disease">[disease Q]...
# 17  <span class="chemical">[chemical B]</span> can...
# 18  Statins can cause a necrotizing myopathy and h...
# 19  Two patients with similar clinical features ar...
# 20  Two patients with similar clinical features ar...
# 21  Male Sprague-Dawley rats were treated with <sp...
# 22  <p>BACKGROUND: A previous randomized controlle...
# 23  <p>BACKGROUND: A previous randomized controlle...
# 24  <p>BACKGROUND: A previous randomized controlle...
# 25  <p>BACKGROUND: A previous randomized controlle...
# 26  We prospectively evaluated the adverse reactio...
# 27  We prospectively evaluated the adverse reactio...
# 28  <p>BACKGROUND: The septo-hippocampal cholinerg...
# 29  <p>BACKGROUND: The septo-hippocampal cholinerg...
# 30  <p>BACKGROUND: The septo-hippocampal cholinerg...
# 31  <p>BACKGROUND: The septo-hippocampal cholinerg...
# 32  Twenty common <span class="disease">[disease Q...
# 33  The bronchodilator effects of a single dose of...
# 34  A patient who received <span class="chemical">...
# 35  Two patients treated with parenteral <span cla...
# 36  Two patients treated with parenteral <span cla...
# 37  <span class="disease">[disease S]</span> was o...
# 38  <span class="disease">[disease Q]</span> is a ...
# 39  <span class="chemical">[chemical A]</span> is ...
# 40  The co-administration of <span class="chemical...
# 41  The co-administration of <span class="chemical...
# 42  <p>BACKGROUND: Inhibition of cardiac sympathet...
# 43  <p>BACKGROUND: Inhibition of cardiac sympathet...
# 44  Massive urinary protein excretion has been obs...
# 45  Two patients developed <span class="disease">[...
# 46  Two patients developed <span class="disease">[...
# 47  <p>BACKGROUND AND PURPOSE: The Intravenous <sp...
# 48  A 14-year-old girl is reported with recurrent,...
# 49  <p>BACKGROUND: Markers of fibrinolysis, thromb...
# 50  <p>BACKGROUND: Markers of fibrinolysis, thromb...
#
#                                            form_title      pmid    uniq_id
# 0   Pharmacokinetic/pharmacodynamic assessment of ...  11569530   bcv_id_0
# 1   Pharmacokinetic/pharmacodynamic assessment of ...  11569530   bcv_id_1
# 2   <span class="chemical">[chemical A]</span>, ci...  11135224   bcv_id_2
# 3   Paclitaxel, <span class="chemical">[chemical B...  11135224   bcv_id_3
# 4   Paclitaxel, cisplatin, and <span class="chemic...  11135224   bcv_id_4
# 5   Effects of uninephrectomy and high protein fee...   1378968   bcv_id_5
# 6   Effects of uninephrectomy and high protein fee...   1378968   bcv_id_6
# 7   Effects of uninephrectomy and high protein fee...   1378968   bcv_id_7
# 8   Explicit episodic memory for sensory-discrimin...  19269743   bcv_id_8
# 9   <span class="chemical">[chemical B]</span> pre...   8595686   bcv_id_9
# 10  Thiopentone pretreatment for propofol injectio...   8595686  bcv_id_10
# 11  Investigation of mitochondrial involvement in ...  16337777  bcv_id_11
# 12  The haemodynamic effects of <span class="chemi...  10520387  bcv_id_12
# 13  The haemodynamic effects of propofol in combin...  10520387  bcv_id_13
# 14  A study on the effect of the duration of subcu...  17931375  bcv_id_14
# 15  <span class="disease">[disease R]</span> due t...   3800626  bcv_id_15
# 16  The effect of different anaesthetic agents in ...   9522143  bcv_id_16
# 17  Progressive <span class="disease">[disease P]<...  17241784  bcv_id_17
# 18  Progressive myopathy with up-regulation of MHC...  17241784  bcv_id_18
# 19  Serial <span class="disease">[disease R]</span...   2265898  bcv_id_19
# 20  Serial <span class="disease">[disease R]</span...   2265898  bcv_id_20
# 21  <span class="chemical">[chemical A]</span>-ind...   6666578  bcv_id_21
# 22  Spironolactone-induced <span class="disease">[...  15632880  bcv_id_22
# 23  Spironolactone-induced <span class="disease">[...  15632880  bcv_id_23
# 24  Spironolactone-induced <span class="disease">[...  15632880  bcv_id_24
# 25  <span class="chemical">[chemical E]</span>-ind...  15632880  bcv_id_25
# 26  Evaluation of adverse reactions of <span class...   8590259  bcv_id_26
# 27  Evaluation of adverse reactions of <span class...   8590259  bcv_id_27
# 28  The relationship between hippocampal <span cla...  12198388  bcv_id_28
# 29  The relationship between hippocampal acetylcho...  12198388  bcv_id_29
# 30  The relationship between hippocampal acetylcho...  12198388  bcv_id_30
# 31  The relationship between hippocampal acetylcho...  12198388  bcv_id_31
# 32  Source of <span class="disease">[disease P]</s...   2515254  bcv_id_32
# 33  Acute bronchodilating effects of <span class="...   1835291  bcv_id_33
# 34  <span class="chemical">[chemical B]</span> in ...  12041669  bcv_id_34
# 35  Pseudo-<span class="disease">[disease P]</span...   7582165  bcv_id_35
# 36  Pseudo-<span class="disease">[disease P]</span...   7582165  bcv_id_36
# 37  <span class="chemical">[chemical A]</span>-ind...   2096243  bcv_id_37
# 38  Late, late <span class="chemical">[chemical A]...   7449470  bcv_id_38
# 39  Possible intramuscular <span class="chemical">...   2375138  bcv_id_39
# 40  Effect of <span class="chemical">[chemical B]<...   6692345  bcv_id_40
# 41  Effect of <span class="chemical">[chemical B]<...   6692345  bcv_id_41
# 42  Direct inhibition of cardiac hyperpolarization...  17261653  bcv_id_42
# 43  Direct inhibition of cardiac hyperpolarization...  17261653  bcv_id_43
# 44  mToR inhibitors-induced <span class="disease">...  18631865  bcv_id_44
# 45  <span class="disease">[disease R]</span> of co...   1130930  bcv_id_45
# 46  <span class="disease">[disease R]</span> of co...   1130930  bcv_id_46
# 47  Effect of intravenous <span class="chemical">[...  10835440  bcv_id_47
# 48  Recurrent acute <span class="disease">[disease...  15602202  bcv_id_48
# 49  The effects of short-term <span class="chemica...  16167916  bcv_id_49
# 50  The effects of short-term raloxifene therapy o...  16167916  bcv_id_50

# %%
cf_data.to_csv("data/crowdflower/data_for_cf_job_.tsv", sep = '\t', index = False)
